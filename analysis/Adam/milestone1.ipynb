# %%
import pandas as pd

# %%
pd.read_csv("../../data/raw/mlb_elo_latest.csv")
# Out:
#             date  season  neutral  playoff team1 team2     elo1_pre  \
# 0     2021-10-03    2021        0      NaN   ATL   NYM  1522.348303
# 1     2021-10-03    2021        0      NaN   STL   CHC  1491.709838
# 2     2021-10-03    2021        0      NaN   SEA   ANA  1489.919377
# 3     2021-10-03    2021        0      NaN   LAD   MIL  1585.624562
# 4     2021-10-03    2021        0      NaN   KCR   MIN  1443.484602
# ...          ...     ...      ...      ...   ...   ...          ...
# 2423  2021-04-01    2021        0      NaN   PHI   ATL  1499.854980
# 2424  2021-04-01    2021        0      NaN   CHC   PIT  1510.606166
# 2425  2021-04-01    2021        0      NaN   MIL   MIN  1502.386929
# 2426  2021-04-01    2021        0      NaN   DET   CLE  1450.437505
# 2427  2021-04-01    2021        0      NaN   NYY   TOR  1540.629874
#
#          elo2_pre  elo_prob1  elo_prob2  ...  pitcher1_rgs  pitcher2_rgs  \
# 0     1513.261073   0.547473   0.452527  ...           NaN           NaN
# ...
